# %%
# Importing the necessary libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
# Reading the data from a csv file

data = pd.read_csv('train.csv')
data
# Out:
#         Id  MSSubClass MSZoning  ...  SaleType  SaleCondition SalePrice
# 0        1          60       RL  ...        WD         Normal    208500
# 1        2          20       RL  ...        WD         Normal    181500
# 2        3          60       RL  ...        WD         Normal    223500
# 3        4          70       RL  ...        WD        Abnorml    140000
# 4        5          60       RL  ...        WD         Normal    250000
# ...    ...         ...      ...  ...       ...            ...       ...
# 1455  1456          60       RL  ...        WD         Normal    175000
# 1456  1457          20       RL  ...        WD         Normal    210000
# 1457  1458          70       RL  ...        WD         Normal    266500
# 1458  1459          20       RL  ...        WD         Normal    142125
# 1459  1460          20       RL  ...        WD         Normal    147500
#
# [1460 rows x 81 columns]

# %%
# Analysing the data using the describe() function

data.describe()
# Out:
#                 Id   MSSubClass  ...       YrSold      SalePrice
# count  1460.000000  1460.000000  ...  1460.000000    1460.000000
# mean    730.500000    56.897260  ...  2007.815753  180921.195890
# std     421.610009    42.300571  ...     1.328095   79442.502883
# min       1.000000    20.000000  ...  2006.000000   34900.000000
# 25%     365.750000    20.000000  ...  2007.000000  129975.000000
# 50%     730.500000    50.000000  ...  2008.000000  163000.000000
# 75%    1095.250000    70.000000  ...  2009.000000  214000.000000
# max    1460.000000   190.000000  ...  2010.000000  755000.000000
#
# [8 rows x 38 columns]

# %%
# plotting the heatmap of the data to check correlation between features

plt.figure(figsize=(22,22))
sns.heatmap(data[list(data.dtypes[data.dtypes!='object'].index)].corr(),annot=True)
plt.show()

# %%
# Dropping one of the features between 2 highly correlated features (>0.8)

data.drop(['GarageYrBlt', 'GarageCars', 'TotRmsAbvGrd'], axis=1, inplace=True)

# %%
# Checking if the dataset has any NaN values

data.isna().values.any()
# Out:
# True

# %%
# Finding out which columns have NaN values

print(data.isna().sum())
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 78, dtype: int64

# %%
for column in data.columns:
  if data[column].isna().sum()>0:
    print(column)
    print(data[column].isna().sum())
# Out:
# LotFrontage
# 259
# Alley
# 1369
# MasVnrType
# 8
# MasVnrArea
# 8
# BsmtQual
# 37
# BsmtCond
# 37
# BsmtExposure
# 38
# BsmtFinType1
# 37
# BsmtFinType2
# 38
# Electrical
# 1
# FireplaceQu
# 690
# GarageType
# 81
# GarageFinish
# 81
# GarageQual
# 81
# GarageCond
# 81
# PoolQC
# 1453
# Fence
# 1179
# MiscFeature
# 1406

# %%
# Features with very high NaN values

print(data['Alley'].isna().sum())
print(data['FireplaceQu'].isna().sum())
print(data['PoolQC'].isna().sum())
print(data['Fence'].isna().sum())
print(data['MiscFeature'].isna().sum())
print(data['LotFrontage'].isna().sum())

data.shape
# Out:
# 1369
# 690
# 1453
# 1179
# 1406
# 259
# (1460, 78)

# %%
# Dropping the features with very high NaN values

data.drop(['Alley', 'FireplaceQu', 'PoolQC', 'Fence', 'MiscFeature', 'LotFrontage'], axis = 1, inplace=True)

data.drop(['Id'], axis=1, inplace=True) # Dropping Id as its redundant

# %%
data.shape
# Out:
# (1460, 71)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
# Label Encoding the categorical variables

LE = LabelEncoder()
CategoryList = data.select_dtypes(include="object").columns
print(CategoryList)
# Out:
# Index(['MSZoning', 'Street', 'LotShape', 'LandContour', 'Utilities',
#        'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2',
#        'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st',
#        'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation',
#        'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
#        'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual',
#        'Functional', 'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond',
#        'PavedDrive', 'SaleType', 'SaleCondition'],
#       dtype='object')

# %%
for i in CategoryList:
    data[i] = LE.fit_transform(data[i])
data.head()
# Out:
#    MSSubClass  MSZoning  LotArea  ...  SaleType  SaleCondition  SalePrice
# 0          60         3     8450  ...         8              4     208500
# 1          20         3     9600  ...         8              4     181500
# 2          60         3    11250  ...         8              4     223500
# 3          70         3     9550  ...         8              0     140000
# 4          60         3    14260  ...         8              4     250000
#
# [5 rows x 71 columns]

# %%
# Imputing the data (Filling the missing values with median of the feature)

from sklearn.impute import SimpleImputer

imputer = SimpleImputer(missing_values = np.nan, strategy ='median')

# Fitting the data to the imputer object
imputer = imputer.fit(data)
 
# Imputing the data    
data = pd.DataFrame(imputer.transform(data), columns=data.columns)

# %%
# Checking if data has any missing values again, should come False now

data.isna().values.any()
# Out:
# False

# %%
data.head()
# Out:
#    MSSubClass  MSZoning  LotArea  ...  SaleType  SaleCondition  SalePrice
# 0        60.0       3.0   8450.0  ...       8.0            4.0   208500.0
# 1        20.0       3.0   9600.0  ...       8.0            4.0   181500.0
# 2        60.0       3.0  11250.0  ...       8.0            4.0   223500.0
# 3        70.0       3.0   9550.0  ...       8.0            0.0   140000.0
# 4        60.0       3.0  14260.0  ...       8.0            4.0   250000.0
#
# [5 rows x 71 columns]

# %%
data.shape
# Out:
# (1460, 71)

# %%
# Using MinMaxScaler to scale the distribution between 0 and 1

from sklearn.preprocessing import MinMaxScaler

X = data.drop(['SalePrice'], axis=1)
y = data['SalePrice']

scaler = MinMaxScaler()
X = pd.DataFrame(scaler.fit_transform(X), columns=X.columns)

X.head()
# Out:
#    MSSubClass  MSZoning   LotArea  ...  YrSold  SaleType  SaleCondition
# 0    0.235294      0.75  0.033420  ...    0.50       1.0            0.8
# 1    0.000000      0.75  0.038795  ...    0.25       1.0            0.8
# 2    0.235294      0.75  0.046507  ...    0.50       1.0            0.8
# 3    0.294118      0.75  0.038561  ...    0.00       1.0            0.0
# 4    0.235294      0.75  0.060576  ...    0.50       1.0            0.8
#
# [5 rows x 70 columns]

# %%
# Splitting the data into training and testing Sets

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=123)

print(X_train.shape, X_test.shape)
print(y_train.shape, y_test.shape)
# Out:
# (1095, 70) (365, 70)
# (1095,) (365,)

# %%
# Fitting the training data into a Linear Regression model

from sklearn.linear_model import LinearRegression
model = LinearRegression().fit(X_train, y_train)
model.score(X_train, y_train)
# Out:
# 0.837445827179376

# %%
# Predicting the Sale Price of testing set

y_pred = model.predict(X_test)

# %%
# Finding the mean squared error 

from sklearn.metrics import mean_squared_error
import math

print(math.sqrt(mean_squared_error(y_test, y_pred)))
# Out:
# 28427.178949832953

# %%
# Printing the r2_score, which shows how much of the data has fit well into the LR Model

from sklearn.metrics import r2_score

print(r2_score(y_test, y_pred))
# Out:
# 0.86599675769631

# %%
# Plotting a scatter plot to compare the Actual values vs Predicted Values of Sale Price

plt.figure(figsize=(10,10))
plt.scatter(y_test, y_pred)

plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')

plt.title('Actual vs Predicted')
# Out:
# Text(0.5, 1.0, 'Actual vs Predicted')
